# %% [markdown]
# # Applied Data Science Capstone - Coursera
# # The Battle of Neighborhoods - Report

# %% [markdown]
# ## Introduction
# New York City has a large amount of Japanese inhabitants, and the numbers keep increasing yearly. New York City also welcomes many Japanese tourists each year. Because of these factors (and many more), interest in the Japanese culture among New Yorkers are increasing.
#
# The traditional American diet is considered unhealthy. As more Americans are becoming health conscious, more people are turning to a healthier alternative in Japanese food.
#
# With this in mind, a New York City inhabitant of Japanese descent, a Japanese tourist, or a famished health conscious patron interested in the Japanese culture would all be asking "Where do I find the best Japanese food in New York City?".

# %% [markdown]
# ## Data
#
# In order to answer the above question, data on New York City neighborhoods and boroughs, to include boundaries, latitude, longitude, restaurants, restaurant ratings, and tips are required.
#
# New York City data containing the neighborhoods and boroughs, latitudes, and longitudes will be obtained from the data source: https://cocl.us/new_york_dataset
#
# All data related to locations and quality of Japanese restaurants will be obtained via the FourSquare API utilized via the Request library in Python.

# %% [markdown]
# ## Methodology
#
# - Data will be collected from https://cocl.us/new_york_dataset, cleaned and processed into a dataframe.
#
# - FourSquare be used to locate all venues and then filtered by Japanese restaurants. Ratings, tips, and likes by users will be counted and added to the dataframe.
#
# - Data will be sorted based on rankings.
#
# - Finally, the data will be visually assessed using graphing from Python libraries.

# %% [markdown]
# ## Results
# 50 Japanese restaurant in New York City were identified and analysed.
#
# Samurai Mama in North Side, Brooklyn has the largest amount of likes (899).
#
# Kura in the East Village of Manhattan has the higest ranking (9.3 on a scale of 1 to 10).
#
# Morimoto in Chelsea, Manhattan has the largest amount of tips (791).
#
# Neighborhoods with the highest average rating:

# %% [markdown]
# ![Neighborhoods_highest_ranking.JPG](attachment:Neighborhoods_highest_ranking.JPG)

# %% [markdown]
# Average ratings of Japanese Restaurants for each Borough:

# %% [markdown]
# ![Average_per_borough.JPG](attachment:Average_per_borough.JPG)

# %% [markdown]
# Let's visualise this:

# %% [markdown]
# ![Average_per_borough_visual.JPG](attachment:Average_per_borough_visual.JPG)

# %% [markdown]
# Average ratings of Japanese Restaurants for each neighborhood:

# %% [markdown]
# ![Average_per_neighborhood.JPG](attachment:Average_per_neighborhood.JPG)

# %% [markdown]
# ## Discussion
#
# Manhattan and Brooklyn have the best rated Japanese restaurants on average and Staten Island and The Bronx have the least amount of Japanese restaurants per borough. Despite Manhattan having the least number of neighborhoods in all five boroughs, it has the most number of Japanese restaurants.
#
# Based on the above information, I would state that Manhattan and Brooklyn are the best locations for Japanese cuisine in NYC.
#
# To have the best Japanese meal in NYC, I would visit Manhattan. Manhattan has multiple neighborhoods with average ratings exceeding 8.0 on a scale of 1.0 to 10.0. The best neighborhoods would be the East Village. I would suggest Kura in the East Village for the best Japanese food, based on the highest average ranking of 9.3.

# %% [markdown]
# ## Conclusion
#
# New York City neighborhood and borough data was gather from a data source and cleaned, after which the Foursquare API was used to gather data on Japanese restaurants in these neighborhoods. The gathered data was analysed visually, after which the conslusion was that the best neighborhood to visit in NYC for Japanese cuisine is the East Village in Manhattan.
